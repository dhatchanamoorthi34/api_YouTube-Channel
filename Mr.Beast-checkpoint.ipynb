# %% [markdown]
# <h1 id="This-Dataset-has-Video-stats-for-the-MrBeast-Youtube-Channel">This Dataset has Video stats for the MrBeast Youtube </h1>

# %% [markdown]
# ![Presentation3(1).jpg](attachment:4f686206-8fe5-41ce-b520-386983c1b421.jpg)

# %%
import pandas as pd
import numpy as np
from dateutil import parser
import isodate

# Data visualization libraries
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

# Google API
from googleapiclient.discovery import build

# %%
api_key = 'AIzaSyB9nKehmaaGrmYH_Y_vAxZvVRru60voeFM'

# %%
channel_ids = ['UCX6OQ3DkcsbYNE6H8uQQuVA',
               # more channels here
              ]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    """
    Get channel stats
    
    Params:
    ------
    youtube: build object of Youtube API
    channel_ids: list of channel IDs
    
    Returns:
    ------
    dataframe with all channel stats for each channel ID
    
    """
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return pd.DataFrame(all_data)

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids
    
    
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %% [markdown]
# ### Get channel statistics

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#   channelName subscribers        views totalVideos                playlistId
# 0     MrBeast   199000000  34592784716         759  UUX6OQ3DkcsbYNE6H8uQQuVA

# %%
# Get video details
playlist_id = "UUX6OQ3DkcsbYNE6H8uQQuVA"

# %%
# Get video IDs
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 759

# %%
# Get video details
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#         video_id channelTitle  \
# 0    3ryID_SwU5E      MrBeast
# 1    IemzxkkzI5s      MrBeast
# 2    3OFj6l2tQ9s      MrBeast
# 3    bvlFjrcpD6s      MrBeast
# 4    AZlBZuS4hr0      MrBeast
# ..           ...          ...
# 754  7qj3nuF9Dzw      MrBeast
# 755  Y74b7WlcEpk      MrBeast
# 756  Z8nEEdXTaX0      MrBeast
# 757  jP82d277Cc8      MrBeast
# 758  2XVcLrB7B3Y      MrBeast
#
#                                                  title  \
# 0                            $1 Vs $100,000,000 House!
# 1               I Tipped A Pizza Delivery Driver A Car
# 2                         World's Most Dangerous Trap!
# 3                             I NEED 1 MORE SUBSCRIBER
# 4                              Guess The Gift, Keep It
# ..                                                 ...
# 754               Most Epic minecraft skin EVER  (Psy)
# 755                          More birds IN MINECRAFT!!
# 756                     Boxy item mod Minecraft.  EPIC
# 757  Harry Potter Mod In Minecraft! EPIC MUST SEE M...
# 758                   Worst Minecraft Saw Trap Ever???
#
#                                            description  \
# 0    I can’t believe how expensive the last house i...
# 1
# 2    I can’t believe how crazy the last room is\nGr...
# 3
# 4
# ..                                                 ...
# 754  Psy in minecraft!!!   drop a like for psy's mo...
# 755  Basically what this mod does is adds more bird...
# 756  At the begining i said i was mrbeast6000.... i...
# 757  One of the coolest mods i have ever seen\n\nMo...
# 758  This is the worst saw trap ever done in minecr...
#
#                                                   tags           publishedAt  \
# 0                                                 None  2023-10-14T16:00:00Z
# 1                                                 None  2023-10-12T17:30:03Z
# 2                                                 None  2023-10-07T16:00:00Z
# 3                                                 None  2023-10-05T17:00:01Z
# 4                                                 None  2023-10-03T17:00:00Z
# ..                                                 ...                   ...
# 754           [psy, minecraft, epic, skin, most, ever]  2013-01-13T01:59:21Z
# 755      [birds, minecraft, in, more, must, see, epic]  2013-01-12T23:35:45Z
# 756                 [boxy, item, mod, minecraft, epic]  2013-01-12T22:34:11Z
# 757  [Harry Potter minecraft, minecraft, minecraft ...  2012-03-09T23:29:03Z
# 758  [minecraft, saw trap, minecraft saw trap, wors...  2012-02-20T22:42:32Z
#
#      viewCount likeCount favouriteCount commentCount  duration definition  \
# 0     33199190   2101547           None        65671  PT17M36S         hd
# 1     33253923   2540176           None         8384     PT52S         hd
# 2    112318503   4824730           None       141209  PT19M48S         hd
# 3    130987369  11924721           None        41866     PT22S         hd
# 4    153560260   7730136           None         7935     PT45S         hd
# ..         ...       ...            ...          ...       ...        ...
# 754     807266     31930           None         3069     PT31S         hd
# 755     937675     37271           None         3353    PT2M6S         hd
# 756    1113201     44114           None         4024   PT1M30S         hd
# 757    3958299      None           None         7951   PT3M59S         hd
# 758   19330205    916188           None       111502   PT2M37S         hd
#
#     caption
# 0      true
# 1     false
# 2      true
# 3     false
# 4     false
# ..      ...
# 754   false
# 755   false
# 756   false
# 757   false
# 758   false
#
# [759 rows x 13 columns]

# %%
def get_comments_in_videos(youtube, video_ids):
   
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %% [markdown]
# ### Get video statistics

# %%
# Check for NULL values
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount          True
# favouriteCount     True
# commentCount       True
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
# Check data types
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# Convert count columns to numeric
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
# Publish day in the week
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs', 'duration']]
# Out:
#      durationSecs  duration
# 0          1056.0  PT17M36S
# 1            52.0     PT52S
# 2          1188.0  PT19M48S
# 3            22.0     PT22S
# 4            45.0     PT45S
# ..            ...       ...
# 754          31.0     PT31S
# 755         126.0    PT2M6S
# 756          90.0   PT1M30S
# 757         239.0   PT3M59S
# 758         157.0   PT2M37S
#
# [759 rows x 2 columns]

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    3ryID_SwU5E      MrBeast
# 1    IemzxkkzI5s      MrBeast
# 2    3OFj6l2tQ9s      MrBeast
# 3    bvlFjrcpD6s      MrBeast
# 4    AZlBZuS4hr0      MrBeast
# ..           ...          ...
# 754  7qj3nuF9Dzw      MrBeast
# 755  Y74b7WlcEpk      MrBeast
# 756  Z8nEEdXTaX0      MrBeast
# 757  jP82d277Cc8      MrBeast
# 758  2XVcLrB7B3Y      MrBeast
#
#                                                  title  \
# 0                            $1 Vs $100,000,000 House!
# 1               I Tipped A Pizza Delivery Driver A Car
# 2                         World's Most Dangerous Trap!
# 3                             I NEED 1 MORE SUBSCRIBER
# 4                              Guess The Gift, Keep It
# ..                                                 ...
# 754               Most Epic minecraft skin EVER  (Psy)
# 755                          More birds IN MINECRAFT!!
# 756                     Boxy item mod Minecraft.  EPIC
# 757  Harry Potter Mod In Minecraft! EPIC MUST SEE M...
# 758                   Worst Minecraft Saw Trap Ever???
#
#                                            description  \
# 0    I can’t believe how expensive the last house i...
# 1
# 2    I can’t believe how crazy the last room is\nGr...
# 3
# 4
# ..                                                 ...
# 754  Psy in minecraft!!!   drop a like for psy's mo...
# 755  Basically what this mod does is adds more bird...
# 756  At the begining i said i was mrbeast6000.... i...
# 757  One of the coolest mods i have ever seen\n\nMo...
# 758  This is the worst saw trap ever done in minecr...
#
#                                                   tags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 754           [psy, minecraft, epic, skin, most, ever]
# 755      [birds, minecraft, in, more, must, see, epic]
# 756                 [boxy, item, mod, minecraft, epic]
# 757  [Harry Potter minecraft, minecraft, minecraft ...
# 758  [minecraft, saw trap, minecraft saw trap, wors...
#
#                   publishedAt    viewCount   likeCount  favouriteCount  \
# 0   2023-10-14 16:00:00+00:00   33199190.0   2101547.0             NaN
# 1   2023-10-12 17:30:03+00:00   33253923.0   2540176.0             NaN
# 2   2023-10-07 16:00:00+00:00  112318503.0   4824730.0             NaN
# 3   2023-10-05 17:00:01+00:00  130987369.0  11924721.0             NaN
# 4   2023-10-03 17:00:00+00:00  153560260.0   7730136.0             NaN
# ..                        ...          ...         ...             ...
# 754 2013-01-13 01:59:21+00:00     807266.0     31930.0             NaN
# 755 2013-01-12 23:35:45+00:00     937675.0     37271.0             NaN
# 756 2013-01-12 22:34:11+00:00    1113201.0     44114.0             NaN
# 757 2012-03-09 23:29:03+00:00    3958299.0         NaN             NaN
# 758 2012-02-20 22:42:32+00:00   19330205.0    916188.0             NaN
#
#      commentCount  duration definition caption pushblishDayName  durationSecs  \
# 0         65671.0  PT17M36S         hd    true         Saturday        1056.0
# 1          8384.0     PT52S         hd   false         Thursday          52.0
# 2        141209.0  PT19M48S         hd    true         Saturday        1188.0
# 3         41866.0     PT22S         hd   false         Thursday          22.0
# 4          7935.0     PT45S         hd   false          Tuesday          45.0
# ..            ...       ...        ...     ...              ...           ...
# 754        3069.0     PT31S         hd   false           Sunday          31.0
# 755        3353.0    PT2M6S         hd   false         Saturday         126.0
# 756        4024.0   PT1M30S         hd   false         Saturday          90.0
# 757        7951.0   PT3M59S         hd   false           Friday         239.0
# 758      111502.0   PT2M37S         hd   false           Monday         157.0
#
#      tagCount
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 754         6
# 755         7
# 756         5
# 757         6
# 758         4
#
# [759 rows x 16 columns]

# %%
ax = sns.barplot(x='viewCount', y='title', data=video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_yticklabels(), rotation=50)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'k'))
# Out:
# C:\Users\dhatc\AppData\Local\Temp\ipykernel_6884\2341505175.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot = ax.set_xticklabels(ax.get_yticklabels(), rotation=50)

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <Axes: xlabel='likeCount', ylabel='viewCount'>

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins=30)
# Out:
# <Axes: xlabel='durationSecs', ylabel='Count'>

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "durationSecs", y = "commentCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "durationSecs", y = "likeCount", ax=ax[1])
# Out:
# <Axes: xlabel='durationSecs', ylabel='likeCount'>

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)
